# %%
import os
import openpyxl

def rename_excel_files():
    current_directory = os.getcwd()
    for filename in os.listdir(current_directory):
        if filename.endswith('.xlsx') or filename.endswith('.xls'):
            new_filename = filename.replace("CG4 ", "").replace("-", "").replace('_preprocessed',"").replace('E0','E')
            if new_filename != filename:
                os.rename(os.path.join(current_directory, filename), os.path.join(current_directory, new_filename))
                print(f"Renamed '{filename}' to '{new_filename}'")

rename_excel_files()
# Out:
# Renamed 'ERNE01.xlsx' to 'ERNE1.xlsx'
# Renamed 'ERNE02.xlsx' to 'ERNE2.xlsx'
# Renamed 'ERNE03.xlsx' to 'ERNE3.xlsx'
# Renamed 'ERNE05.xlsx' to 'ERNE5.xlsx'
# Renamed 'ERNE07.xlsx' to 'ERNE7.xlsx'
# Renamed 'ERNE08.xlsx' to 'ERNE8.xlsx'
# Renamed 'ERNE09.xlsx' to 'ERNE9.xlsx'
