# %%
import pandas as pd
# !pip install pandas
import os
import glob
import traceback
import matplotlib.pyplot as plt

import numpy as np
from numpy import diff
import math


import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[10,4]
plt.rcParams.update({'font.size':18})

from decimal import Decimal, getcontext
from scipy.signal import find_peaks, peak_prominences
from scipy.ndimage import interpolation

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #Suppress annoying Pandas Message

import os
import openpyxl
from openpyxl.drawing.image import Image
import io
# get_ipython().system('pip install XlsxWriter')


# Ensure plots are displayed inline in the Jupyter Notebook
# %matplotlib inline

# Define the directory to search for .xlsx files (current directory)
directory = os.getcwd()

# Find all .xlsx files in the directory
all_files = glob.glob(os.path.join(directory, '*.xlsx'))

# Define a list of files to exclude
excluded_files = ['QA Log.xlsx', 'Experiment Tracker.xlsx']  # Replace with actual file names to exclude

# Filter out the excluded files, hidden files, and temporary Excel files
file_names = [os.path.splitext(os.path.basename(file))[0]  # Get the base name without extension
              for file in all_files
              if (os.path.basename(file) not in excluded_files and 
                  not os.path.basename(file).startswith('~$') and  # Exclude temporary Excel files
                  not os.path.basename(file).startswith('.'))]   # Exclude hidden files

# Define your sheet_name list
sheet_names = [
    'T0-1', 'T5-6', 'T10-11', 'T15-16', 'T20-21', 'T25-26', 'T29-30', 'T30-T31', 
    'T35-36', 'T40-41', 'T45-46', 'T50-51', 'T55-56', 'T59-60', 'T60-61', 
    'T64-65', 'T65-66', 'T70-71', 'T74-75', 'T75-76', 'T80-81', 'T84-85', 'T85-86','T90-91',
    'T120-121', 'T180-181', 'T239-240'
]
# Initialize an empty list to log failed combinations
failed_combinations = []

# Configuration: Set to True to enable plotting, False to disable
enable_plotting = False

# Function to process data for a specific file_name and sheet_name
def process_data(file_name, sheet_name):
    try:

        #!/usr/bin/env python
        # coding: utf-8

        # ## Import necessary python packages

        # In[1]:


        base_file_name = file_name.replace('.xlsx', '')
        print(base_file_name)

#         file_name=base_file_name+'.xlsx'

        data_output=('{}_{}'.format(base_file_name,sheet_name))
        print(data_output)


        # In[2]:

        import numpy as np
        from numpy import diff
        import math
        import pandas as pd

        import seaborn as sns
        import matplotlib.pyplot as plt
        plt.rcParams['figure.figsize']=[10,4]
        plt.rcParams.update({'font.size':18})

        from decimal import Decimal, getcontext
        from scipy.signal import find_peaks, peak_prominences
        from scipy.ndimage import interpolation

        import warnings
        warnings.simplefilter(action='ignore', category=FutureWarning) #Suppress annoying Pandas Message

        import os
        import openpyxl
        from openpyxl.drawing.image import Image
        import io

        # ## User Inputs

        # In[3]:


        time_step=.005
        # pressure_index=1
        # volume_index=2
        # zoom_factor=12


        # In[4]:
        print("start")

        #Import Raw Data
        print(file_name)
        temp_file_name=file_name+'.xlsx'
        print(temp_file_name)
        PV_Raw = pd.read_excel(temp_file_name, sheet_name=sheet_name)
        print('data copied')

        print("Column names in the DataFrame are:")
        print(PV_Raw.columns)


        # In[5]:


        # # Ask the user for the flow data unit
        # flow_unit = input("Is the flow data in mL/min or L/min? Enter 'mL' or 'L': ")

        # Check if "mL/min" appears in the entire PV_Raw DataFrame
        if "mL/min" in str(PV_Raw.to_string()):
            flow_unit = "mL"
            i=1
        else:
            flow_unit = "l"

        print(flow_unit)
        # Set the flow conversion factor based on the user's input
        if flow_unit.lower() == 'l':
            flow_conversion_factor = 1e3  # If it's L/min, convert to mL/min
        else:
            flow_conversion_factor = 1  # If it's already in mL/min, no conversion needed

        print(f'Flow conversion factor set to: {flow_conversion_factor}')


        # In[6]:


        PV_Raw = PV_Raw[~PV_Raw.applymap(lambda x: isinstance(x, str)).all(axis=1)]
        # PV_Raw=PV_Raw.astype(float)


        # In[7]:


        # #Import Time Points

        # headers=['ERNE16']
        # ########################################
        # header_index=0
        # ########################################
        # ########################################
        # sheet_index=0

        # ########################################

        # base_file_name=headers[header_index]

        # df=pd.read_excel('Catalogue.xlsx', 'Time Periods')
        # df=df.loc[:,base_file_name]

        # df = df.dropna()
        # file_name=base_file_name+'.xlsx'

        # sheet_name=str(int(df.loc[sheet_index]))
        # sheet_name_abs=sheet_name
        # data_output=('{}_T{}'.format(headers[header_index],sheet_name))
        # print(data_output)


        # In[8]:





        # In[9]:





        # In[ ]:





        # In[10]:
    

        # Set the flow conversion factor based on the user's input
        if flow_unit.lower() == 'l':
#             PV_Raw = PV_Raw.drop(PV_Raw.columns[0], axis=1)
            vol = np.array(PV_Raw['LVV'], dtype=float)
            press = np.array(PV_Raw['LVP'], dtype=float)
            phase = np.array(PV_Raw['Phase'], dtype=float)
            mag = np.array(PV_Raw['Magnitude'], dtype=float)



            carotid_flow=flow_conversion_factor*np.array(PV_Raw['CarotidQ'], dtype=float)



            RTJug_pressure = np.array(PV_Raw['RtJug/CVP'], dtype=float)
            balloon_pressure = np.array(PV_Raw['Balloon Press'], dtype=float)
            ECG = np.array(PV_Raw['ECG'], dtype=float)



        #     AOBalloon_flow = flow_conversion_factor*np.array(PV_Raw['AoBalloonQ'], dtype=float)
        #     dist_press = np.array(PV_Raw['RtFem/DistalP'], dtype=float)
        #     asc_flow = flow_conversion_factor*np.array(PV_Raw['AscAoQ'], dtype=float)
        #     dist_flow = flow_conversion_factor*np.array(PV_Raw['DistalAoQ'], dtype=float)
        #     prox_pressure = np.array(PV_Raw['LSA/Prox-P'], dtype=float)
        # #     prox_pressure = np.array(PV_Raw['LSA/ProxP.1'], dtype=float)
        #     renal_flow = flow_conversion_factor*np.array(PV_Raw['RenalQ'], dtype=float)
        #     brachiocephalic_flow = flow_conversion_factor*np.array(PV_Raw['BrachioCQ'], dtype=float)

#             prox_pressure = np.array(PV_Raw['LSA/Prox-P.1'], dtype=float)

            possible_column_names = ['LSA/Prox-P.1', 'LSA/Prox-P', 'LSA/Prox']

            # Try to find the column and convert it to a numpy array
            for col_name in possible_column_names:
                try:
                    prox_pressure = np.array(PV_Raw[col_name], dtype=float)
                    break  # Exit the loop if successful
                except KeyError:
                    continue  # Try the next column name if KeyError is raised
            else:
                # If none of the columns are found, raise an exception or handle the error
                raise KeyError("None of the possible column names were found in the DataFrame.")



#             import numpy as np

#             # Assuming 'PV_Raw' is defined and you want to find the best matching column name
#             possible_column_names = ['LSA/Prox-P.1', 'LSA/Prox-P', 'LSA/Prox', ...]  # Add more possible column names as needed

#             # Function to find the best matching column name
#             def find_best_matching_column(df, possible_names):
#                 for name in possible_names:
#                     if name in df.columns:
#                         return name
#                 return None  # Return None if no matching column is found

#             # Find the best matching column name
#             column_name = find_best_matching_column(PV_Raw, possible_column_names)

#             # If a matching column name is found, proceed to read it
#             if column_name:
#                 try:
#                     prox_pressure = np.array(PV_Raw[column_name], dtype=float)
#                 except (KeyError, ValueError, TypeError):
#                     prox_pressure = np.array([])  # Assign an empty array or handle the error as needed
#             else:
#                 prox_pressure = np.array([])  # If no matching column name is found

#             # Now 'prox_pressure' will be defined based on the best matching column name found

            
            dist_flow = flow_conversion_factor*np.array(PV_Raw['DDA-Q'], dtype=float)
            dist_press = np.array(PV_Raw['RtFem/Distal-P'], dtype=float)
            AOBalloon_flow = flow_conversion_factor*np.array(PV_Raw[' PDA-Q (Balloon)'], dtype=float)    
            asc_flow = flow_conversion_factor*np.array(PV_Raw['AA-Q'], dtype=float)
            renal_flow = flow_conversion_factor*np.array(PV_Raw['Renal-Q'], dtype=float)
            brachiocephalic_flow = flow_conversion_factor*np.array(PV_Raw['BCA-Q'], dtype=float)

        else:
            vol = np.array(PV_Raw['LVV'], dtype=float)
            press = np.array(PV_Raw['LVP'], dtype=float)
            phase = np.array(PV_Raw['Phase'], dtype=float)
            mag = np.array(PV_Raw['Magnitude'], dtype=float)
            asc_flow = flow_conversion_factor*np.array(PV_Raw['AscAoQ'], dtype=float)
            renal_flow = flow_conversion_factor*np.array(PV_Raw['RenalQ'], dtype=float)
            brachiocephalic_flow = flow_conversion_factor*np.array(PV_Raw['BrachioCQ'], dtype=float)

            prox_pressure = np.array(PV_Raw['LSA/Prox P'], dtype=float)
            # prox_pressure = np.array(PV_Raw['LSA/ProxP'], dtype=float)

            dist_flow = flow_conversion_factor*np.array(PV_Raw['DistalAoQ'], dtype=float)
            carotid_flow=flow_conversion_factor*np.array(PV_Raw['Carotid Q'], dtype=float)
            dist_press = np.array(PV_Raw['Rt Fem/Distal P'], dtype=float)
            RTJug_pressure = np.array(PV_Raw['Rt Jug/CVP'], dtype=float)
            balloon_pressure = np.array(PV_Raw['Balloon Press'], dtype=float)
            ECG = np.array(PV_Raw['ECG'], dtype=float)
            AOBalloon_flow = flow_conversion_factor*np.array(PV_Raw['AoBalloonQ'], dtype=float)


        # In[11]:


        # Check if any pressure values go below 0
        if np.any(press < 0):
            min_val = np.min(press)  # Find the minimum value in the array
            if min_val < 0:
                press += np.abs(min_val)  # Add the absolute value of the lowest negative number


        # In[12]:


        # vol = np.array(PV_Raw['LVV'], dtype=float)
        # press = np.array(PV_Raw['LVP'], dtype=float)
        # phase = np.array(PV_Raw['Phase'], dtype=float)
        # mag = np.array(PV_Raw['Magnitude'], dtype=float)
        # asc_flow = flow_conversion_factor*np.array(PV_Raw['AscAoQ'], dtype=float)
        # renal_flow = flow_conversion_factor*np.array(PV_Raw['RenalQ'], dtype=float)
        # brachiocephalic_flow = flow_conversion_factor*np.array(PV_Raw['BrachioCQ'], dtype=float)

        # prox_pressure = flow_conversion_factor*np.array(PV_Raw['LSA/Prox P'], dtype=float)
        # # prox_pressure = flow_conversion_factor*np.array(PV_Raw['LSA/ProxP'], dtype=float)

        # dist_flow = flow_conversion_factor*np.array(PV_Raw['DistalAoQ'], dtype=float)
        # carotid_flow=flow_conversion_factor*np.array(PV_Raw['Carotid Q'], dtype=float)
        # dist_press = np.array(PV_Raw['Rt Fem/Distal P'], dtype=float)
        # RTJug_pressure = np.array(PV_Raw['Rt Jug/CVP'], dtype=float)
        # balloon_pressure = np.array(PV_Raw['Balloon Press'], dtype=float)
        # ECG = np.array(PV_Raw['ECG'], dtype=float)
        # AOBalloon_flow = flow_conversion_factor*np.array(PV_Raw['AoBalloonQ'], dtype=float)





        # vol = np.array(PV_Raw['LVV'], dtype=float)
        # press = np.array(PV_Raw['LVP'], dtype=float)
        # phase = np.array(PV_Raw['Phase'], dtype=float)
        # mag = np.array(PV_Raw['Magnitude'], dtype=float)
        # asc_flow = flow_conversion_factor*np.array(PV_Raw['AA-Q'], dtype=float)
        # renal_flow = flow_conversion_factor*np.array(PV_Raw['Renal-Q'], dtype=float)
        # brachiocephalic_flow = flow_conversion_factor*np.array(PV_Raw['BCA-Q'], dtype=float)

        # prox_pressure = flow_conversion_factor*np.array(PV_Raw['LSA/Prox-P'], dtype=float)
        # # prox_pressure = flow_conversion_factor*np.array(PV_Raw['LSA/Prox-P.1'], dtype=float)

        # dist_flow = flow_conversion_factor*np.array(PV_Raw['DDA-Q'], dtype=float)
        # carotid_flow=flow_conversion_factor*np.array(PV_Raw['CarotidQ'], dtype=float)
        # dist_press = np.array(PV_Raw['RtFem/Distal-P'], dtype=float)
        # RTJug_pressure = np.array(PV_Raw['RtJug/CVP'], dtype=float)
        # balloon_pressure = np.array(PV_Raw['Balloon Press'], dtype=float)
        # ECG = np.array(PV_Raw['ECG'], dtype=float)
        # AOBalloon_flow = flow_conversion_factor*np.array(PV_Raw[' PDA-Q (Balloon)'], dtype=float)


        # In[13]:


        time_array=np.linspace(0,(int(len(vol))+1)*time_step,int(len(vol)))


        # In[ ]:





        # ## Using PV Sense's base code, obtain pseudo-pyshiological PV loops via polar coordinates and define the estimated starting point of each systolic+diastolic combination.

        # In[14]:


        #Define cartesian to polar conversion.
        def cart2pol(x, y):
            theta = np.arctan2(y, x)
            radius = np.sqrt(x**2 + y**2)
            return theta, radius


        #Define the origin from the averages of all of the points
        Pressure_origin=np.mean(press)
        Volume_origin=np.mean(vol)


        #Convert from cartesian to polar coordinates
        theta_array,radius_array=cart2pol(vol-Volume_origin,press-Pressure_origin)

        #Determine where there is a "new" PV loop based on an arbitrary x-axis relative to the "origin"
        PV_Loop_Start=[]
        #Define a 'for' loop over the entire length of the array to determine where the "new" PV loops start
        for step in range(1, len(radius_array)):
            if theta_array[step]>=0 and theta_array[step-1]<0:
                #Just as seen in Stonko's code, we will use an arbitrary x-axis where a shift in the signs for the theta from positive to negative values
                PV_Loop_Start.append(step)
        #print('The Pseudo-Physiological PV Loops Start at the following places: {}'.format(PV_Loop_Start))


        # ## From the list of pseudo-physiological starting points, define the size of each individual loop. Take the smallest size and obtain a scaling factor so we can efficiently begin to find dP/dt max+min¶
        # 

        # In[15]:


        #Get the average distances between each element
#         differences=np.diff(PV_Loop_Start)
        differences = np.diff(PV_Loop_Start)[1:-1]

        #Obtain a scaling factor from the list of differences in order to 
        dp_dt_scaling_factor=0.8*np.min(differences)


        # In[ ]:





        # ## Create and plot the dP/dt waveform¶

        # In[16]:


        #Code to find values such as dP/dt
        def d_dt(y,t):
            derivatives=[]
            np.seterr(invalid='ignore')
            dydt=np.diff(y)/np.diff(t)
            dydt=np.insert(dydt,0,0)
            return dydt

        dPdt= d_dt(press, time_array)

        fig = plt.figure(figsize=(20, 6))
        # plt.plot(time_array, dPdt)
        # plt.title('dP/dt')
        # plt.show()


        # ## Hunt for the dP/dt max and min using the peaks algorithm. Min will be found by flipping the waveform upside down. Correction factor previously found was implemented here in line 9.

        # In[17]:


        def PeakCalculator (data, data_name):
            plot_total_graphs(data, data_name)
            plt.plot(data)
            plt.show()
            #Create user input for height

        #     peak_guess=input('Define a number that would be a "good" guess for the lowest of all the peaks: @TONY JUST WRITE 0, I FIXED THIS FOR YOU')
        #     peak_guess=float(peak_guess)
            peak_guess=0

            #And determine the peaks
            peaks, _ = find_peaks(data, height=peak_guess,distance=dp_dt_scaling_factor)
            plot_total_graphs(data,data_name)
            plt.plot(data)
            for x, y in zip(peaks, data[peaks]):
                plt.text(x, y, str(x), color="red", fontsize=12)
            plt.plot(peaks, data[peaks], "x")
            plt.show()
            return peaks

        def plot_total_graphs(data,data_name):
            fig, ax = plt.subplots(figsize=(25, 5))
            ax.set_xlabel('Time', fontsize=12, color='black')
            ax.set_ylabel('{}'.format(data_name), fontsize=12, color='black')
            plt.xticks(fontsize=10, color='black')
            plt.yticks(fontsize=10, color='black')
            plt.title("{} vs Time".format(data_name), fontsize=12, color='black')


        # ## Find dP/dt max and min's points

        # In[18]:


        def round_up_to_odd(f):
            return np.ceil(f) // 2 * 2 + 1
        # from scipy.signal import savgol_filter
        #dPdtLVP=savgol_filter(dPdtLVP, int(round_up_to_odd(len(dPdtLVP)/150)), 3)

        dPdt_MAX=PeakCalculator(dPdt, 'dp/dt Max')
        dPdt_MIN=PeakCalculator(-dPdt, 'NEGATIVE OF dp/dt')


        # In[19]:


        dPdt_MAX


        # ## Define Rescaling Algorithm

        # In[20]:


        #Resize data in order to obtain a more physiologically relevant sizing for the array
        def ResizeArray (np_array, desired_size):
            z = desired_size / len(np_array)
            reshaped_np_array = interpolation.zoom(np_array,z)
            return reshaped_np_array


        # #vol
        # #press
        # #phase
        # #mag
        # #asc_flow
        # #renal_flow
        # #brachiocephalic_flow
        # #prox_pressure
        # #dist_flow
        # #dist_press
        # #RTJug_pressure
        # #balloon_pressure
        # #ECG
        # #AOBalloon_flow
        # #time_array

        # ## Separate all of the individual data

        # In[21]:


        vol_raw=[]
        press_raw=[]
        phase_raw=[]
        mag_raw=[]
        asc_flow_raw=[]
        renal_flow_raw=[]
        brachiocephalic_flow_raw=[]
        prox_pressure_raw=[]
        dist_flow_raw=[]
        carotid_flow_raw=[]
        dist_press_raw=[]
        RTJug_pressure_raw=[]
        balloon_pressure_raw=[]
        ECG_raw=[]
        AOBalloon_flow_raw=[]
        chunk_size=[]


        for i in range(len(dPdt_MAX) - 1):
            start_idx = dPdt_MAX[i]
            end_idx = dPdt_MAX[i+1]  
        #     dummy_values = vol[start_idx:end_idx]
        #     vol_raw.append(values)

            vol_raw.append(vol[start_idx:end_idx])
            press_raw.append(press[start_idx:end_idx])
            phase_raw.append(phase[start_idx:end_idx])
            mag_raw.append(mag[start_idx:end_idx])
            asc_flow_raw.append(asc_flow[start_idx:end_idx])
            renal_flow_raw.append(renal_flow[start_idx:end_idx])
            brachiocephalic_flow_raw.append(brachiocephalic_flow[start_idx:end_idx])
            prox_pressure_raw.append(prox_pressure[start_idx:end_idx])
            dist_flow_raw.append(dist_flow[start_idx:end_idx])

            carotid_flow_raw.append(carotid_flow[start_idx:end_idx])



            dist_press_raw.append(dist_press[start_idx:end_idx])
            RTJug_pressure_raw.append(RTJug_pressure[start_idx:end_idx])
            balloon_pressure_raw.append(balloon_pressure[start_idx:end_idx])
            ECG_raw.append(ECG[start_idx:end_idx])
            AOBalloon_flow_raw.append(AOBalloon_flow[start_idx:end_idx])
            #Get chunk size
            chunk_size.append(end_idx-start_idx)


        # ## Pass the uneven data into an excel file

        # In[22]:


        # Manually define resized_variables and unaveraged_data
        raw_variables = [vol_raw, press_raw, phase_raw, mag_raw, asc_flow_raw,
                         renal_flow_raw, brachiocephalic_flow_raw, prox_pressure_raw,
                         dist_flow_raw, carotid_flow_raw, dist_press_raw,
                         RTJug_pressure_raw, balloon_pressure_raw, ECG_raw, AOBalloon_flow_raw]


        unaveraged_data = ['Vol', 'Press', 'Phase', 'Mag', 'Asc flow', 'Renal flow', 'Brachiocephalic flow',
                          'Prox pressure', 'Dist flow', 'Carotid flow', 'Dist press', 'Rtjug pressure',
                          'Balloon pressure', 'Ecg', 'Aoballoon flow']

        os.makedirs(os.path.join(base_file_name, sheet_name), exist_ok=True)

        output_folder = os.path.join(base_file_name, sheet_name)
        os.makedirs(output_folder, exist_ok=True)
        file_path = os.path.join(output_folder, 'Raw.xlsx')

        # Create a Pandas Excel writer using XlsxWriter as the engine
        with pd.ExcelWriter(file_path, engine="xlsxwriter") as writer:
            for i in range(len(raw_variables)):
                array_name = unaveraged_data[i]
                array = raw_variables[i]

                # Check if the array is not empty before creating a DataFrame and sheet
                if len(array) > 0:
                    df = pd.DataFrame(array)  # No column label specified
                    df.to_excel(writer, sheet_name=array_name, index=False)


        # In[ ]:





        # In[ ]:





        # ## Get the ensemble time vector

        # In[23]:


        average_vector_size = int(round(np.mean(chunk_size),0))
        average_time = np.mean(chunk_size) * time_step
        # num_points = int(np.ceil(average_time / time_step)) 

        ensemble_time = np.linspace(0, (average_vector_size - 1) * time_step, average_vector_size)


        # ## Resize each element and put it into a new array

        # In[24]:


        vol_resized = []
        press_resized = []
        phase_resized = []
        mag_resized = []
        asc_flow_resized = []
        renal_flow_resized = []
        brachiocephalic_flow_resized = []
        prox_pressure_resized = []
        dist_flow_resized = []
        carotid_flow_resized = []
        dist_press_resized = []
        RTJug_pressure_resized = []
        balloon_pressure_resized = []
        ECG_resized = []
        AOBalloon_flow_resized = []

        for i in range(len(vol_raw)):    
            vol_resized.append(ResizeArray(vol_raw[i], average_vector_size))
            press_resized.append(ResizeArray(press_raw[i], average_vector_size))
            phase_resized.append(ResizeArray(phase_raw[i], average_vector_size))
            mag_resized.append(ResizeArray(mag_raw[i], average_vector_size))
            asc_flow_resized.append(ResizeArray(asc_flow_raw[i], average_vector_size))
            renal_flow_resized.append(ResizeArray(renal_flow_raw[i], average_vector_size))
            brachiocephalic_flow_resized.append(ResizeArray(brachiocephalic_flow_raw[i], average_vector_size))
            prox_pressure_resized.append(ResizeArray(prox_pressure_raw[i], average_vector_size))
            dist_flow_resized.append(ResizeArray(dist_flow_raw[i], average_vector_size))

            carotid_flow_resized.append(ResizeArray(carotid_flow_raw[i], average_vector_size))

            dist_press_resized.append(ResizeArray(dist_press_raw[i], average_vector_size))
            RTJug_pressure_resized.append(ResizeArray(RTJug_pressure_raw[i], average_vector_size))
            balloon_pressure_resized.append(ResizeArray(balloon_pressure_raw[i], average_vector_size))
            ECG_resized.append(ResizeArray(ECG_raw[i], average_vector_size))
            AOBalloon_flow_resized.append(ResizeArray(AOBalloon_flow_raw[i], average_vector_size))


        # ## Plot the incremental data bits which have been resized to  the same length

        # In[25]:


        os.makedirs(os.path.join(base_file_name, sheet_name), exist_ok=True)

        title='Asc. Aorta Q'
        for i in asc_flow_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()


        title='BCA Q'
        for i in brachiocephalic_flow_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='L. Carotid Q'
        for i in carotid_flow_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='Prox. Aorta Q'
        for i in AOBalloon_flow_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='Distal Aorta Q'
        for i in dist_flow_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='Renal Q'
        for i in renal_flow_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='Jugular Vein (CVP)'
        for i in RTJug_pressure_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='LSA Pressure'
        for i in prox_pressure_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()


        title='Femoral-Distal Pressure'
        for i in dist_press_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()


        title='Balloon Pressure'
        for i in balloon_pressure_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()


        title='LV Pressure'
        for i in press_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()




        title='LV Volume'
        for i in vol_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='Phase'
        for i in phase_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()



        title='Magnitude'
        for i in mag_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()

        title='ECG'
        for i in ECG_resized:
            plt.plot(ensemble_time, i)
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()


        # In[26]:


        # Manually define resized_variables and unaveraged_data
        resized_variables = [vol_resized, press_resized, phase_resized, mag_resized, asc_flow_resized,
                             renal_flow_resized, brachiocephalic_flow_resized, prox_pressure_resized,
                             dist_flow_resized, carotid_flow_resized, dist_press_resized,
                             RTJug_pressure_resized, balloon_pressure_resized, ECG_resized, AOBalloon_flow_resized]

        unaveraged_data = ['Vol', 'Press', 'Phase', 'Mag', 'Asc flow', 'Renal flow', 'Brachiocephalic flow',
                          'Prox pressure', 'Dist flow', 'Carotid flow', 'Dist press', 'Rtjug pressure',
                          'Balloon pressure', 'Ecg', 'Aoballoon flow']

        os.makedirs(os.path.join(base_file_name, sheet_name), exist_ok=True)

        output_folder = os.path.join(base_file_name, sheet_name)
        os.makedirs(output_folder, exist_ok=True)
        file_path = os.path.join(output_folder, 'Resized_Raw.xlsx')

        # Create a Pandas Excel writer using XlsxWriter as the engine
        with pd.ExcelWriter(file_path, engine="xlsxwriter") as writer:
            for i in range(len(resized_variables)):
                array_name = unaveraged_data[i]
                array = resized_variables[i]

                # Check if the array is not empty before creating a DataFrame and sheet
                if len(array) > 0:
                    df = pd.DataFrame(array)  # No column label specified
                    df.to_excel(writer, sheet_name=array_name, index=False)


        # ## And then obtain the average for each

        # In[27]:


        def average_maker (list):
            # Combine the numpy arrays into one giant numpy array
            combined_array = np.concatenate(list)
        #     print(combined_array)
            # Reshape the combined array into a 2D array with equal-sized rows
            num_arrays = len(list)
        #     print(num_arrays)
            array_size = list[0].shape[0]
            average_array = combined_array.reshape(num_arrays, array_size)
        #     print(average_array)
            # Compute the average of each row
            row_averages = np.mean(average_array, axis=0)
        #     print(row_averages)

            return row_averages


        # In[28]:


        vol_mean = average_maker(vol_resized)
        press_mean = average_maker(press_resized)
        phase_mean = average_maker(phase_resized)
        mag_mean = average_maker(mag_resized)
        asc_flow_mean = average_maker(asc_flow_resized)
        renal_flow_mean = average_maker(renal_flow_resized)
        brachiocephalic_flow_mean = average_maker(brachiocephalic_flow_resized)
        prox_pressure_mean = average_maker(prox_pressure_resized)
        dist_flow_mean = average_maker(dist_flow_resized)

        carotid_flow_mean = average_maker(carotid_flow_resized)

        dist_press_mean = average_maker(dist_press_resized)
        RTJug_pressure_mean = average_maker(RTJug_pressure_resized)
        balloon_pressure_mean = average_maker(balloon_pressure_resized)
        ECG_mean = average_maker(ECG_resized)
        AOBalloon_flow_mean = average_maker(AOBalloon_flow_resized)


        # ## Plot these ensemble averages

        # In[29]:


        plt.plot(ensemble_time,asc_flow_mean)
        title='Asc. Aorta Q'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name,title, sheet_name))
        plt.savefig(file_path,dpi=300, bbox_inches = "tight")
        plt.show()
        plt.close()


        plt.plot(ensemble_time, brachiocephalic_flow_mean)
        title = 'BCA Q'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, carotid_flow_mean)
        title = 'L. Carotid Q'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, AOBalloon_flow_mean)
        title = 'Prox. Aorta Q'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, dist_flow_mean)
        title = 'Distal Aorta Q'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, renal_flow_mean)
        title = 'Renal Q'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, RTJug_pressure_mean)
        title = 'Jugular Vein (CVP)'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, prox_pressure_mean)
        title = 'LSA Pressure'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, dist_press_mean)
        title = 'Femoral-Distal Pressure'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, balloon_pressure_mean)
        title = 'Balloon Pressure'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, press_mean)
        title = 'LV Pressure'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, vol_mean)
        title = 'LV Volume'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, phase_mean)
        title = 'Phase'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, mag_mean)
        title = 'Magnitude'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()

        plt.plot(ensemble_time, ECG_mean)
        title = 'ECG'
        plt.title(title)
        plt.xlabel('Time')
        plt.ylabel(title)
        file_path = os.path.join(base_file_name, sheet_name, 'ENSEMBLE-{}_{}_T{}.jpg'.format(base_file_name, title, sheet_name))
        plt.savefig(file_path, dpi=300, bbox_inches="tight")
        plt.show()
        plt.close()


        # ## Comment Containing all Available Ensemble Average Data
        # 
        # ## PV
        # ECG_mean
        # vol_mean
        # press_mean
        # phase_mean
        # mag_mean
        # 
        # ## Flow
        # asc_flow_mean
        # renal_flow_mean
        # brachiocephalic_flow_mean
        # AOBalloon_flow_mean
        # dist_flow_mean
        # carotid_flow_mean
        # 
        # ## Pressure
        # prox_pressure_mean
        # dist_press_mean
        # RTJug_pressure_mean
        # balloon_pressure_mean

        # In[30]:


        # ## PV
        # ECG_mean
        # vol_mean
        # press_mean
        # phase_mean
        # mag_mean

        # ## Flow
        # asc_flow_mean
        # renal_flow_mean
        # brachiocephalic_flow_mean
        # AOBalloon_flow_mean
        # dist_flow_mean
        # carotid_flow_mean

        # ## Pressure
        # prox_pressure_mean
        # dist_press_mean
        # RTJug_pressure_mean
        # balloon_pressure_mean


        # In[ ]:





        # In[31]:


        arrays = [ECG_mean, vol_mean, press_mean, phase_mean, mag_mean, asc_flow_mean, renal_flow_mean,
                  brachiocephalic_flow_mean, AOBalloon_flow_mean, dist_flow_mean, carotid_flow_mean,
                  prox_pressure_mean, dist_press_mean, RTJug_pressure_mean, balloon_pressure_mean]

        # Assuming that the names of the arrays are stored in a list as well
        array_names = ["ECG Ensemble", "vol Ensemble", "press Ensemble", "phase Ensemble", "mag Ensemble", "asc_flow Ensemble",
                       "renal_flow Ensemble", "brachiocephalic_flow Ensemble", "AOBalloon_flow Ensemble",
                       "dist_flow Ensemble", "carotid_flow Ensemble", "prox_pressure Ensemble", "dist_press Ensemble",
                       "RTJug_pressure Ensemble", "balloon_pressure Ensemble"]


        os.makedirs(os.path.join(base_file_name, sheet_name), exist_ok=True)


        # os.makedirs(output_folder, exist_ok=True)
        data_sheet='Raw Ensemble Data'
        # Create the output path using os.path.join



        # file_path = os.path.join(base_file_name, sheet_name, '{}_{}_T{}.xlsx'.format(base_file_name, data_sheet, sheet_name))

        # # Create a Pandas Excel writer using XlsxWriter as the engine
        # with pd.ExcelWriter(file_path, engine="xlsxwriter") as writer:
        #     for i in range(len(arrays)):
        #         array_name = array_names[i]
        #         array = arrays[i]
        #         df = pd.DataFrame({"ensemble_time": ensemble_time, array_name: array})
        #         df.to_excel(writer, sheet_name=array_name, index=False)


        # In[32]:


        # Calculate minimum, maximum, and mean values for each array
        min_values = [np.min(arr) for arr in arrays]
        max_values = [np.max(arr) for arr in arrays]
        mean_values = [np.mean(arr) for arr in arrays]

        # Create a DataFrame to store the statistics
        statistics_df = pd.DataFrame({'Array Name': array_names, 'Minimum': min_values, 'Maximum': max_values, 'Mean': mean_values})

        # Set 'Array Name' as the index (optional, can be omitted)
        statistics_df.set_index('Array Name', inplace=True)

        # Transpose the DataFrame to have array names as columns and statistics as rows
        statistics_df = statistics_df.T


        # Specify the output folder and file path

        output_folder = os.path.join(base_file_name, sheet_name)
        os.makedirs(output_folder, exist_ok=True)
        file_path = os.path.join(output_folder, '{}_{}_T{}.xlsx'.format(base_file_name, data_sheet, sheet_name))

        # Create a Pandas Excel writer using XlsxWriter as the engine
        with pd.ExcelWriter(file_path, engine="xlsxwriter") as writer:
            # Save the statistics_df to its own worksheet
            statistics_df.to_excel(writer, sheet_name='Statistics', index=True)    
            for i in range(len(arrays)):
                array_name = array_names[i]
                array = arrays[i]
                df = pd.DataFrame({"ensemble_time": ensemble_time, array_name: array})
                df.to_excel(writer, sheet_name=array_name, index=False)


        # ## Obtain the converted data for all data types

        # In[33]:


        pressure_convert=133.32
        flow_convert=16666.67*10**3
        flow_convert=16666.67/10**3
        # flow_convert=16666.67

        def data_sort(inp,conversion):
            avg= np.average(inp)
            avg_conv=avg*conversion
            maxim=np.max(inp)
            maxim_conv=maxim*conversion
            minim=np.min(inp)
            minim_conv=minim*conversion
            data=[avg,avg_conv,maxim,maxim_conv,minim,minim_conv]
            return data


        # ## Flow Data

        # In[34]:


        asc_flow_data = data_sort(asc_flow_mean, flow_convert)
        AOBalloon_flow_data = data_sort(AOBalloon_flow_mean, flow_convert)
        renal_flow_data = data_sort(renal_flow_mean, flow_convert)
        brachiocephalic_flow_data = data_sort(brachiocephalic_flow_mean, flow_convert)
        dist_flow_data = data_sort(dist_flow_mean, flow_convert)
        carotid_flow_data = data_sort(carotid_flow_mean, flow_convert)


        # ## Pressure Data

        # In[35]:


        dist_press_data = data_sort(dist_press_mean, pressure_convert)
        RTJug_pressure_data = data_sort(RTJug_pressure_mean, pressure_convert)
        balloon_pressure_data = data_sort(balloon_pressure_mean, pressure_convert)
        prox_pressure_data = data_sort(prox_pressure_mean, pressure_convert)

        #Output: data=[avg,avg_conv,maxim,maxim_conv,minim,minim_conv]


        # ##  (MAY NOT HAVE USE)-Separete the Positive and Negative Components
        # ### NOTE: the function needs to be fixed

        # In[36]:


        def average_positive_negative(data):
            positive_numbers = [num for num in data if num > 0]
            negative_numbers = [num for num in data if num < 0]

            avg_positive = sum(positive_numbers) / len(positive_numbers) if positive_numbers else 0
            avg_negative = sum(negative_numbers) / len(negative_numbers) if negative_numbers else 0

            return avg_positive, avg_negative


        # ## Data Split Calculation

        # In[37]:


        AscendingQ_avg = asc_flow_data[1]

        AOBalloon_flow_avg = AOBalloon_flow_data[1]
        BrachioFlow_avg = brachiocephalic_flow_data[1]
        LSAFlow_avg = AscendingQ_avg - AOBalloon_flow_avg - BrachioFlow_avg
        carotid_flow_avg = carotid_flow_data [1]
        RSA_flow_avg= BrachioFlow_avg-2*carotid_flow_avg


        # print(BrachioFlow_avg)

        # print(RSA_flow_avg)

        # print(carotid_flow_avg)

        DistFlow_avg = dist_flow_data[1]
        RenalFlow_avg = renal_flow_data[1]

        Celiac_Mesentary_remainder_avg = AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg
        Celiac_avg = (AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg)*5.36/9.56
        SMA_avg = (AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg)*3.21/9.56 
        IMA_avg = (AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg)/9.56
        # carotid_flow_data[1]


        # In[ ]:





        # In[38]:


        # #Using unconverted data
        # AscendingQ_mean=asc_flow_data[0]
        # ProxFlow_mean=AOBalloon_flow_data[0]
        # BrachioFlow_mean=brachiocephalic_flow_data[0]
        # LSAFlow_mean=AscendingQ_mean-ProxFlow_mean-BrachioFlow_mean

        # DistFlow_mean=dist_flow_data[0]
        # RenalFlow_mean=renal_flow_data[0]

        # Celiac_Mesentary_remainder_mean=ProxFlow_mean-DistFlow_mean-2*RenalFlow_mean
        # # carotid_flow_data[0]


        # In[39]:


        # print(AscendingQ_avg)
        # print(ProxFlow_avg)
        # print(BrachioFlow_avg)
        # print(LSAFlow_avg)
        # print(DistFlow_avg)
        # print(RenalFlow_avg)
        # print(Celiac_Mesentary_remainder_avg)


        # In[40]:


        # Append their flow splits
        asc_flow_data.append(1)
        AOBalloon_flow_data.append(AOBalloon_flow_avg / AscendingQ_avg)
        brachiocephalic_flow_data.append(BrachioFlow_avg / AscendingQ_avg)
        LSAFlow_data = [LSAFlow_avg / AscendingQ_avg]

        ###############################################################
        carotid_flow_data.append(carotid_flow_avg / AscendingQ_avg)
        RSAFlow_data = [RSA_flow_avg / AscendingQ_avg]
        ##############################################################

        dist_flow_data.append(DistFlow_avg / AscendingQ_avg)
        renal_flow_data.append(RenalFlow_avg / AscendingQ_avg)

        Celiac_Mesentary_remainder_data = [Celiac_Mesentary_remainder_avg / AscendingQ_avg]
        Celiac_remainder_data = [Celiac_avg / AscendingQ_avg]
        SMA_remainder_data = [SMA_avg / AscendingQ_avg]
        IMA_remainder_data = [IMA_avg / AscendingQ_avg]

        # Celiac = (AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg)*5.36/9.56
        # SMA = (AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg)*3.21/9.56 
        # IMA = (AOBalloon_flow_avg - DistFlow_avg - 2 * RenalFlow_avg)/9.56


        # In[41]:


        # print(Celiac_Mesentary_remainder_avg)
        # print(AOBalloon_flow_avg)
        # print(RSA_flow_avg)


        # In[42]:


        # print(Celiac_Mesentary_remainder_data)
        # print()


        # In[43]:


        # def positive_fraction_before_negative(data):
        #     for i, num in enumerate(data):
        #         if num < 0:
        #             return i / len(data)

        #     return 1.0  # If no negative number found, return 1.0 indicating all data is positive


        def positive_fraction_before_negative(data,time):
            for i, num in enumerate(data[10:]):
                if num < 0:
                    return time[i]

            return 1.0  # If no negative number found, return 1.0 indicating all data after 10 points is positive


        # In[44]:


        R_tot = prox_pressure_data[1] / asc_flow_data[1]
        half_systole = positive_fraction_before_negative(asc_flow_mean,ensemble_time) / 2
        C_tot = (asc_flow_data[3] - asc_flow_data[5]) * half_systole / (prox_pressure_data[3] - prox_pressure_data[5])


        # In[45]:


        # print(asc_flow_data)


        # In[46]:


        # print(R_tot)
        # print(half_systole)
        # print(C_tot)


        # ## Actual RCR calculation

        # In[47]:


        def RCR_calculator(outlet_data,AscendingQ_data,R_tot,prox_factor):
            Qj=AscendingQ_data[1]*outlet_data[-1]
            Rj=AscendingQ_data[1]*R_tot/Qj
            R_prox=prox_factor*Rj
            R_dist=Rj-R_prox
            Capacitance=C_tot*Qj/AscendingQ_data[1]*((R_dist+R_prox)/R_dist)
            RCR_data=[outlet_data[-1],Qj,Rj,R_prox,Capacitance,R_dist]
            return RCR_data


        # In[48]:


        #Obtain each RCR
        AOBalloon_flow_RCR=RCR_calculator(AOBalloon_flow_data,asc_flow_data,R_tot,.06)
        Brachio_RCR=RCR_calculator(brachiocephalic_flow_data,asc_flow_data,R_tot,.1)
        LSA_RCR=RCR_calculator(LSAFlow_data,asc_flow_data,R_tot,.1)
        Celiac_Mesentary_remainder_RCR=RCR_calculator(Celiac_Mesentary_remainder_data,asc_flow_data,R_tot,.06)
        Distal_flow_RCR=RCR_calculator(dist_flow_data,asc_flow_data,R_tot,.06)

        Renal_flow_RCR=RCR_calculator(renal_flow_data,asc_flow_data,R_tot,.06)


        ############################################################
        RSA_RCR=RCR_calculator(RSAFlow_data,asc_flow_data,R_tot,.06)
        carotid_RCR=RCR_calculator(carotid_flow_data,asc_flow_data,R_tot,.06)

        Celiac_remainder_RCR=RCR_calculator(Celiac_remainder_data,asc_flow_data,R_tot,.06)
        SMA_remainder_RCR=RCR_calculator(SMA_remainder_data,asc_flow_data,R_tot,.06)
        IMA_remainder_RCR=RCR_calculator(IMA_remainder_data,asc_flow_data,R_tot,.06)


        # In[ ]:





        # In[49]:


        #Arrange Data
        RCR_output_names=['Flow Split','Qj','Rj','R_prox','Capacitance','R_dist']
        RCR_output=[Brachio_RCR,LSA_RCR,AOBalloon_flow_RCR, Renal_flow_RCR,Celiac_Mesentary_remainder_RCR, Distal_flow_RCR,RSA_RCR, carotid_RCR, Celiac_remainder_RCR, SMA_remainder_RCR, IMA_remainder_RCR]
        RCR_output=np.array(RCR_output)
        #RCR_output=np.transpose(RCR_output)
        RCR_data_names=['Brachio','LSA', 'Prox Desc', 'Renal', 'Celiac Mesentary', 'Distal','RSA', 'Carotid', 'Celiac', 'SMA', 'IMA']
        #RCR_data=np.transpose(RCR_data)


        # In[50]:


        #Store the Data into an excel worl
        RCR=df = pd.DataFrame(RCR_output, columns = RCR_output_names )
        RCR.index = RCR_data_names


        folder_path = os.path.join(base_file_name, sheet_name)

        # Create the folder if it doesn't exist
        os.makedirs(folder_path, exist_ok=True)

        file_path = os.path.join(folder_path, "{}_RCRData.xlsx".format(data_output))
        RCR.to_excel(file_path, index=1)


        # In[ ]:





        # In[51]:


        print('The Pressure in mmHg is {}'.format(prox_pressure_data[0]))
        print('The Pressure in Pa is {}'.format(prox_pressure_data[1]))
        print('The Flow in mL/min is {}'.format(asc_flow_data[0]))


        # In[ ]:





        # # Integrating the Positive and Negative Sides

        # In[52]:


        import numpy as np
        from scipy.integrate import trapz
        import matplotlib.pyplot as plt

        def separate_integrals_and_plot(time, data):
            # Compute the cumulative integral of the data
            integral_values = np.cumsum(data)

            # Find the zero-crossings to separate positive and negative sides
            zero_crossings = np.where(np.diff(np.sign(data)))[0]

            # Create arrays for positive and negative values
            pos_values = np.maximum(data, 0)
            neg_values = np.minimum(data, 0)

        #     # Plot positive values
        #     plt.plot(time, pos_values, label='Positive Values', color='green')

        #     # Plot negative values
        #     plt.plot(time, neg_values, label='Negative Values', color='red')

        #     # Highlight zero-crossings
        #     for crossing in zero_crossings:
        #         plt.axvline(x=time[crossing], color='black', linestyle='--', alpha=0.7)

        #     plt.legend()
        #     plt.title('Positive and Negative Values')
        #     plt.xlabel('Time')
        #     plt.show()

            # Initialize positive and negative integrals
            positive_integral = trapz(integral_values * (data > 0), x=time)
            negative_integral = trapz(integral_values * (data < 0), x=time)

            return positive_integral, negative_integral

        integral_outputs=[]
        average_flows=[asc_flow_mean,renal_flow_mean,brachiocephalic_flow_mean,AOBalloon_flow_mean,dist_flow_mean,carotid_flow_mean]
        for flow in average_flows:
            pos_integral, neg_integral = separate_integrals_and_plot(ensemble_time,flow)
            integrated=[pos_integral,neg_integral]
            print(integrated)
            integral_outputs.append(integrated)


        # Assuming you have a list of labels for each pair
        label_list = ['Ascending Flow','Renal Flow','Brachiocephalic', 'Aortic Balloon', 'Distal Flow', 'Carotid Flow']


        # Create a DataFrame from the list of tuples
        df = pd.DataFrame(integral_outputs, columns=['Positive Integral', 'Negative Integral'], index=label_list)

        # Specify the Excel file name
        excel_filename = "{}_IntegralResults.xlsx".format(data_output)

        # Specify the full file path
        file_path = os.path.join(folder_path, excel_filename)

        # Export the DataFrame to the Excel file
        df.to_excel(file_path, index_label='Label')

        print("DataFrame successfully exported to Excel:", file_path)


        # # Averaging the Positive and Negative Sides

        # In[53]:


        import numpy as np
        import pandas as pd
        import os

        def separate_means_and_plot(time, data):
            # Find the zero-crossings to separate positive and negative sides
            zero_crossings = np.where(np.diff(np.sign(data)))[0]

            # Create arrays for positive and negative values
            pos_values = np.maximum(data, 0)
            neg_values = np.minimum(data, 0)

            # Calculate the mean of positive and negative values
            positive_mean = np.mean(pos_values)
            negative_mean = np.mean(neg_values)

            return positive_mean, negative_mean

        mean_outputs = []
        average_flows = [asc_flow_mean, renal_flow_mean, brachiocephalic_flow_mean, AOBalloon_flow_mean, dist_flow_mean, carotid_flow_mean]

        for flow in average_flows:
            pos_mean, neg_mean = separate_means_and_plot(ensemble_time, flow)
            means = [pos_mean, neg_mean]
            print(means)
            mean_outputs.append(means)

        # Assuming you have a list of labels for each pair
        label_list = ['Ascending Flow', 'Renal Flow', 'Brachiocephalic', 'Aortic Balloon', 'Distal Flow', 'Carotid Flow']

        # Create a DataFrame from the list of tuples
        df = pd.DataFrame(mean_outputs, columns=['Positive Mean', 'Negative Mean'], index=label_list)

        # Specify the Excel file name
        excel_filename = "{}_MeanResults.xlsx".format(data_output)

        # Specify the full file path
        file_path = os.path.join(folder_path, excel_filename)

        # Export the DataFrame to the Excel file
        df.to_excel(file_path, index_label='Label')

        print("DataFrame successfully exported to Excel:", file_path)


        # # Cycle Lengths

        # In[54]:


        # Positive Average/ Normal Average
        # Length of time it is positive
        # Length of time it is negative


        # In[55]:


        import numpy as np
        from scipy.integrate import trapz
        import matplotlib.pyplot as plt

        def cycle_lengths(time, data):

            zero_crossings = np.where(np.diff(np.sign(data)))[0]

            #total time
            total_time=np.max(time)

            # Identify positive and negative values
            pos_values = data[data > 0]
            neg_values = data[data < 0]

            total_length = len(data)        # Length of the original data array
            pos_values_len = len(pos_values)/total_length*total_time  # Number of positive values in the data array
            neg_values_len = len(neg_values)/total_length*total_time  # Number of negative values in the data array

            positive_mean_vs_whole_mean=np.mean(pos_values)/np.mean(data)*100
            negative_mean_vs_whole_mean=np.mean(neg_values)/np.mean(data)*100

            # Create arrays for positive and negative values
            pos_values = np.maximum(data, 0)
            neg_values = np.minimum(data, 0)

            # Calculate the mean of positive and negative values
            positive_mean = np.mean(pos_values)
            negative_mean = np.mean(neg_values)

            whole_mean=np.mean(data)

            percent_pos=pos_values_len/total_time*100
            percent_neg=neg_values_len/total_time*100

            return whole_mean, positive_mean, negative_mean,positive_mean_vs_whole_mean,negative_mean_vs_whole_mean,total_time,pos_values_len, neg_values_len,percent_pos, percent_neg




        cycles_individual=[]
        average_flows=[asc_flow_mean,renal_flow_mean,brachiocephalic_flow_mean,AOBalloon_flow_mean,dist_flow_mean,carotid_flow_mean]
        for flow in average_flows:
            whole_mean, positive_mean, negative_mean,positive_mean_vs_whole_mean,negative_mean_vs_whole_mean,total_time,pos_values_len, neg_values_len,percent_pos, percent_neg = cycle_lengths(ensemble_time, flow)
            cycle=[whole_mean, positive_mean, negative_mean,positive_mean_vs_whole_mean,negative_mean_vs_whole_mean,total_time,pos_values_len, neg_values_len,percent_pos, percent_neg]
            print(cycle)
            cycles_individual.append(cycle)


        # Assuming you have a list of labels for each pair
        label_list = ['Ascending Flow','Renal Flow','Brachiocephalic', 'Aortic Balloon', 'Distal Flow', 'Carotid Flow']


        # Create a DataFrame from the list of tuples
        df = pd.DataFrame(cycles_individual, columns=[    "AA_Q",
            "Positive Mean",
            "Negative Mean",
            "CO_%AA",
            "Cor_%AA",
            "Time of Cycle (s)",
            "Time of Positive (s)",
            "Time of Negative",
            "%Time of Positive",
            "%Time of Negative"], 
            index=label_list)

        # Specify the Excel file name
        excel_filename = "{}_LengthPosORNeg.xlsx".format(data_output)

        # Specify the full file path
        file_path = os.path.join(folder_path, excel_filename)

        # Export the DataFrame to the Excel file
        df.to_excel(file_path, index_label='Label')

        print("DataFrame successfully exported to Excel:", file_path)


        # In[56]:


        # input('A whole new world')


        # # Flow File Generator

        # ## Array Expansion Algorithm

        # ### Resize the original waveform

        # In[57]:


        def ResizeArray (np_array, desired_size):
            z = desired_size / len(np_array)
            reshaped_np_array = interpolation.zoom(np_array,z)
            return reshaped_np_array

        expanded_loop=ResizeArray (asc_flow_mean, int(len(asc_flow_mean)/0.02))


        # ### Duplicate the waveform 5 times and then create a time-array to match it

        # In[58]:


        def array_expansion(original_loop, desired_time_step, number_of_repetitions):
            #Define the new array length 

            #expanded_array_length=int(len(original_loop)/0.0005*number_of_repetitions)
            expanded_array_length=len(original_loop)*number_of_repetitions
            print('5 repititions will give us an array that is {} units long'.format(expanded_array_length))

            #Define an expanded time array
            expanded_time =np.zeros(expanded_array_length)

            for i in range(expanded_array_length):
                expanded_time[i]=i*desired_time_step


            added_CO=original_loop[1:]
            added_CO=original_loop
            expanded_CO=np.copy(original_loop)


            for i in range(number_of_repetitions-1):
                expanded_CO=np.append(expanded_CO,added_CO)

            expanded_CO= -16666.7*expanded_CO/10**3
            #Return the arrays
            return expanded_CO, expanded_time

        desired_time_step=0.0001

        expanded_CO, expanded_time=array_expansion(expanded_loop, desired_time_step, 5)

        # plt.plot(expanded_time,expanded_CO)    
        # plt.show()    


        # In[59]:


        folder_path = os.path.join(base_file_name, sheet_name)

        # Create the folder if it doesn't exist
        os.makedirs(folder_path, exist_ok=True)

        # Create the DataFrame
        Flow_File = pd.DataFrame()
        Flow_File['Expanded Time'] = np.transpose(expanded_time)
        Flow_File['Expanded CO'] = np.transpose(expanded_CO)

        # # Save the DataFrame as a CSV file
        # file_path = os.path.join(folder_path, '{}_flow.flow'.format(data_output))
        # Flow_File.to_csv(file_path, index=False)

        file_path = os.path.join(folder_path, '{}_PULSATILE_flow.flow'.format(data_output))
        np.savetxt(file_path, Flow_File.values, fmt='%s')


        # ## Make steady state

        # In[60]:


        folder_path = os.path.join(base_file_name, sheet_name)

        # Create the folder if it doesn't exist
        os.makedirs(folder_path, exist_ok=True)

        SS_time=np.array([0,1])
        avg_CO=np.mean(expanded_CO)
        SS_CO=np.array([avg_CO,avg_CO])


        # Create the DataFrame
        Flow_File = pd.DataFrame()
        Flow_File['SS Time'] = np.transpose(SS_time)
        Flow_File['SS CO'] = np.transpose(SS_CO)

        # # Save the DataFrame as a CSV file
        # file_path = os.path.join(folder_path, '{}_flow.flow'.format(data_output))
        # Flow_File.to_csv(file_path, index=False)

        file_path = os.path.join(folder_path, '{}_STEADYSTATE_flow.flow'.format(data_output))
        np.savetxt(file_path, Flow_File.values, fmt='%s')


        # In[ ]:





        # In[ ]:





        # #Export to a Flow File
        # def flow_file(time,CO,name):
        #     Flow_File= pd.DataFrame()
        #     Flow_File['Expanded Time']=np.transpose(time)
        #     Flow_File['Expanded CO']= np.transpose(CO)
        #     np.savetxt("{}_flow.flow".format(name), Flow_File)
        #     
        # flow_file(expanded_time,expanded_CO,data_output)

        # ## Fix all of this

        # In[61]:


        #number_of_steps=int(cycle_length*5/time_step)
        number_of_steps=len(expanded_CO)
        print(number_of_steps)

        last_cycle_start=int(number_of_steps-number_of_steps/5)
        print(last_cycle_start)

        last_cycle_stop=number_of_steps
        print('The last cycle starts at')
        print(last_cycle_start)
        print('and stops at')
        print(last_cycle_stop)
        def print_factors(input):
            factors=[]
            print('The prime factors are')
            for i in range(1, input + 1):
                if input % i == 0:
                    factors=np.append(factors,i)
                    print(i)
            return factors

        factors=print_factors(number_of_steps)


        # In[62]:


        possible_choices=[]
        high_priority=[]

        for x in factors:
            if x>=30 and x<=60:
                possible_choices=np.append(possible_choices,x)

        for x in possible_choices:
            if x>=40 and x<=50:
                high_priority=np.append(high_priority,x)
        print('The possible choices between 30 and 60 are')
        print(possible_choices)
        print('The best possible restart values are')
        print(high_priority)


        # In[63]:


        # Define the path for the text file
        text_file_path = os.path.join(output_folder, 'SolverFile.txt')

        # Open the text file for writing
        with open(text_file_path, 'w') as text_file:
            text_file.write('The last cycle starts at\n')
            text_file.write(str(last_cycle_start) + '\n')
            text_file.write('and stops at\n')
            text_file.write(str(last_cycle_stop) + '\n')

            def print_factors(input):
                factors = []
                text_file.write('The prime factors are\n')
                for i in range(1, input + 1):
                    if input % i == 0:
                        factors.append(i)
                        text_file.write(str(i) + '\n')
                return factors

            factors = print_factors(number_of_steps)

            possible_choices = []
            high_priority = []

            for x in factors:
                if x >= 30 and x <= 60:
                    possible_choices.append(x)

            for x in possible_choices:
                if x >= 40 and x <= 50:
                    high_priority.append(x)

            text_file.write('The possible choices between 30 and 60 are\n')
            text_file.write(str(possible_choices) + '\n')
            text_file.write('The best possible restart values are\n')
            text_file.write(str(high_priority) + '\n')

        print(f'Information has been saved to {text_file_path}')


        # In[ ]:






    except Exception as e:
        print(f"Error processing {file_name}.xlsx - {sheet_name}: {e}")
        traceback.print_exc()
        failed_combinations.append((file_name, sheet_name))

# Loop through each file_name and sheet_name and process it
for file_name in file_names:
    for sheet_name in sheet_names:
        try:
            process_data(file_name, sheet_name)
        except Exception as e:
            print(f"Failed to process {file_name}.xlsx - {sheet_name}: {e}")
            traceback.print_exc()
            failed_combinations.append((file_name, sheet_name))

# # Print the log of failed combinations
# if failed_combinations:
#     print("The following combinations failed:")
#     for combo in failed_combinations:
#         print(combo)
# else:
#     print("All combinations processed successfully!")
# Check if there are any failed combinations

# %%
import datetime
if failed_combinations:
    # Get the current date and time
    now = datetime.datetime.now()
    # Format the filename with the current date and time
    filename = f" Flow Presuure Error Report {now.strftime('%Y-%m-%d %H-%M-%S')}.txt"
    
    # Open the file and write the failed combinations
    with open(filename, 'w') as file:
        file.write("The following combinations failed:\n")
        for combo in failed_combinations:
            file.write(f"{combo}\n")
    
    print(f"Error report written to {filename}")
else:
    print("All combinations processed successfully!")
